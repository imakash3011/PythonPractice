# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.linspace(0,10,20)
y=x*x
z=x+y

# %%
plt.plot(x,y,label='first example')
plt.legend()

# %%
plt.plot(x,y,y,x,label="second example")
plt.legend(loc=1)  #you have 1-10 option for  the loc

# %%
plt.plot(x,y)
