# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\imaka\\Python_Programs\\Pandas_DataVisualisation'

# %%
df1=sns.load_dataset('tips')

# %%
df2=pd.read_csv('ece.csv')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2
# Out:
#       Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1           ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2           ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3           ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
# ...                ...      ...         ...         ...    ...      ...
# 16025       ECTQ.S4AXP  2018.03        47.2         NaN      F  Percent
# 16026       ECTQ.S4AXP  2018.06        48.6         NaN      F  Percent
# 16027       ECTQ.S4AXP  2018.09        48.2         NaN      F  Percent
# 16028       ECTQ.S4AXP  2018.12        46.6         NaN      F  Percent
# 16029       ECTQ.S4AXP  2019.03        45.8         NaN      F  Percent
#
#        Magnitude                                        Subject  \
# 0              6  Electronic Card Transactions (ANZSIC06) - ECT
# 1              6  Electronic Card Transactions (ANZSIC06) - ECT
# 2              6  Electronic Card Transactions (ANZSIC06) - ECT
# 3              6  Electronic Card Transactions (ANZSIC06) - ECT
# 4              6  Electronic Card Transactions (ANZSIC06) - ECT
# ...          ...                                            ...
# 16025          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16026          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16027          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16028          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16029          0  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                    Group Series_title_1  \
# 0      Total values - Electronic card transactions A/...         Actual
# 1      Total values - Electronic card transactions A/...         Actual
# 2      Total values - Electronic card transactions A/...         Actual
# 3      Total values - Electronic card transactions A/...         Actual
# 4      Total values - Electronic card transactions A/...         Actual
# ...                                                  ...            ...
# 16025  Electronic card transactions by mean and propo...         Actual
# 16026  Electronic card transactions by mean and propo...         Actual
# 16027  Electronic card transactions by mean and propo...         Actual
# 16028  Electronic card transactions by mean and propo...         Actual
# 16029  Electronic card transactions by mean and propo...         Actual
#
#                                           Series_title_2  Series_title_3  \
# 0                                   RTS total industries             NaN
# 1                                   RTS total industries             NaN
# 2                                   RTS total industries             NaN
# 3                                   RTS total industries             NaN
# 4                                   RTS total industries             NaN
# ...                                                  ...             ...
# 16025  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16026  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16027  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16028  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16029  Debit card usage as a proportion of total ECT ...  Proportion (%)
#
#        Series_title_4  Series_title_5
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
#
#         3.15194073e-01],
#        [3.63253423e-01, 3.44544717e-01, 7.09850591e-01, 8.42874098e-01,
#         9.35220444e-01],
#        [3.64311254e-01, 1.28946736e-01, 1.19283537e-01, 1.66911826e-01,
#         8.47204743e-01],
#        [9.59313842e-01, 9.09317196e-01, 7.08401203e-01, 1.12379966e-02,
#         2.77113539e-01],
#        [5.42717616e-01, 1.06004981e-01, 9.60050229e-01, 2.73405411e-01,
#         4.99890144e-02],
#        [2.78572446e-01, 5.35212854e-01, 9.10174302e-01, 4.55643848e-01,
#         6.76195362e-01],
#        [9.71776125e-01, 2.75720784e-01, 9.90430048e-01, 9.07310008e-01,
#         7.57900037e-01],
#        [9.92884641e-01, 1.17434078e-01, 3.12610015e-02, 2.94757501e-01,
#         1.03219127e-01],
#        [6.06766329e-01, 3.82377699e-01, 8.19646235e-01, 8.22006540e-01,
#         1.68280124e-01],
#        [1.71147800e-01, 9.91751142e-01, 2.17020416e-02, 8.47993850e-01,
#         7.52154283e-01],
#        [7.77776939e-01, 5.95578671e-01, 8.74631133e-01, 4.64299195e-01,
#         8.10987557e-01],
#        [5.24919877e-01, 3.32313252e-01, 8.91365062e-01, 6.16369589e-01,
#         1.78510019e-01]])

# %%
x2=np.random.rand(10,5)

# %%
x2
# Out:
# array([[0.26114406, 0.90611911, 0.61613108, 0.67651787, 0.96875758],
#        [0.62423146, 0.96735391, 0.01707785, 0.7451347 , 0.84485456],
#        [0.88563821, 0.59781275, 0.37101288, 0.31097971, 0.29239828],
#        [0.90978472, 0.554391  , 0.54532141, 0.41861211, 0.58439487],
#        [0.64322283, 0.50917365, 0.70598877, 0.87222068, 0.76972214],
#        [0.58215281, 0.59298795, 0.75557647, 0.10473615, 0.73006115],
#        [0.16193686, 0.91380891, 0.10791518, 0.88579746, 0.99513082],
#        [0.33098041, 0.76675913, 0.33460084, 0.71834444, 0.79944424],
#        [0.14894278, 0.79052981, 0.5331318 , 0.96389652, 0.03843778],
#        [0.65893295, 0.33101288, 0.49274292, 0.00940585, 0.29735123]])

# %%
df3=pd.DataFrame(x1, columns=['a','b','c','d','e'])

# %%
df3
# Out:
#            a         b         c         d         e
# 0   0.192386  0.030933  0.686820  0.769373  0.931095
# 1   0.466079  0.913199  0.223086  0.182346  0.772520
# 2   0.661699  0.549116  0.747860  0.875876  0.567771
# 3   0.800059  0.915723  0.943105  0.817394  0.386392
# 4   0.468515  0.837283  0.547914  0.499276  0.310503
# ..       ...       ...       ...       ...       ...
# 95  0.992885  0.117434  0.031261  0.294758  0.103219
# 96  0.606766  0.382378  0.819646  0.822007  0.168280
# 97  0.171148  0.991751  0.021702  0.847994  0.752154
# 98  0.777777  0.595579  0.874631  0.464299  0.810988
# 99  0.524920  0.332313  0.891365  0.616370  0.178510
#
# [100 rows x 5 columns]

# %%
df4=pd.DataFrame(x2, columns=['a','b','c','d','e'])

# %%
df4
# Out:
#           a         b         c         d         e
# 0  0.261144  0.906119  0.616131  0.676518  0.968758
# 1  0.624231  0.967354  0.017078  0.745135  0.844855
# 2  0.885638  0.597813  0.371013  0.310980  0.292398
# 3  0.909785  0.554391  0.545321  0.418612  0.584395
# 4  0.643223  0.509174  0.705989  0.872221  0.769722
# 5  0.582153  0.592988  0.755576  0.104736  0.730061
# 6  0.161937  0.913809  0.107915  0.885797  0.995131
# 7  0.330980  0.766759  0.334601  0.718344  0.799444
# 8  0.148943  0.790530  0.533132  0.963897  0.038438
# 9  0.658933  0.331013  0.492743  0.009406  0.297351

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df2.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1       ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2       ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3       ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4       ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
#
#    Magnitude                                        Subject  \
# 0          6  Electronic Card Transactions (ANZSIC06) - ECT
# 1          6  Electronic Card Transactions (ANZSIC06) - ECT
# 2          6  Electronic Card Transactions (ANZSIC06) - ECT
# 3          6  Electronic Card Transactions (ANZSIC06) - ECT
# 4          6  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# 1  Total values - Electronic card transactions A/...         Actual
# 2  Total values - Electronic card transactions A/...         Actual
# 3  Total values - Electronic card transactions A/...         Actual
# 4  Total values - Electronic card transactions A/...         Actual
#
#          Series_title_2 Series_title_3  Series_title_4  Series_title_5
# 0  RTS total industries            NaN             NaN             NaN
# 1  RTS total industries            NaN             NaN             NaN
# 2  RTS total industries            NaN             NaN             NaN
# 3  RTS total industries            NaN             NaN             NaN
# 4  RTS total industries            NaN             NaN             NaN

# %%
df3.head()
# Out:
#           a         b         c         d         e
# 0  0.192386  0.030933  0.686820  0.769373  0.931095
# 1  0.466079  0.913199  0.223086  0.182346  0.772520
# 2  0.661699  0.549116  0.747860  0.875876  0.567771
# 3  0.800059  0.915723  0.943105  0.817394  0.386392
# 4  0.468515  0.837283  0.547914  0.499276  0.310503

# %%
df4.head()
# Out:
#           a         b         c         d         e
# 0  0.261144  0.906119  0.616131  0.676518  0.968758
# 1  0.624231  0.967354  0.017078  0.745135  0.844855
# 2  0.885638  0.597813  0.371013  0.310980  0.292398
# 3  0.909785  0.554391  0.545321  0.418612  0.584395
# 4  0.643223  0.509174  0.705989  0.872221  0.769722

# %%
df3.plot.scatter(x='a',y='b')

# %%
df4.plot.scatter(x='a',y='b')

# %%
df1.plot.scatter(x='total_bill',y='tip')

# %%
df3.plot.line()

# %%
df3['a'].plot.line()

# %%
df3['c'].plot.line()

# %%
df4.plot.line()

# %%
df1.plot.kde()

# %%
df3.plot.density()

# %%
df3['a'].plot.density()

# %%
df4.plot.hist()

# %%
df4.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000274DC8DD188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000274DCA1DB08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000274DCA55DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000274DCA8F508>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000274DCACCE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000274DCB01748>]],
#       dtype=object)

# %%
df4['a'].plot.hist()

# %%
df4.plot.bar()

# %%
df4.plot.area()

# %%
df4.plot.area(alpha=0.2)

# %%
df1.plot(kind='hist')

# %%
df4.plot.box()

# %%
df1.plot.hexbin(x='total_bill' , y='tip' , gridsize=15 , cmap='cool')
