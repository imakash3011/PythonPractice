# %% [markdown]
# json    =>  dictionary in python
# CSV     =>  data in files
# excel
# html   =>  #conda install html5lib

# %%
# %%time
pwd
# Out:
# Wall time: 0 ns
# 'C:\\Users\\imaka\\Python_Programs\\Pandas'

# %%
pwd
# Out:
# 'C:\\Users\\imaka\\Python_Programs\\Pandas'

# %%
import pandas as pd

# %%
pd.read_csv('data.csv')
# Out:
#                   variable_name                dataset  \
# 0               budget_cpp_dstb                 Budget
# 1                budget_cpp_mdr                 Budget
# 2                budget_cpp_xdr                 Budget
# 3                    budget_fld                 Budget
# 4                    budget_lab                 Budget
# ..                          ...                    ...
# 490  ptsurvey_newinc_con_prevtx  Policies and services
# 491                  pub_new_dx  Policies and services
# 492         pulm_spec_available  Policies and services
# 493               universal_dst  Policies and services
# 494            wrd_initial_test  Policies and services
#
#                          code_list  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 490                            NaN
# ...

# %%
#if you are directly accessing the file form the internet
x=pd.read_html('https://github.com/codeforamerica/ohana-api/blob/master/data/sample-csv/services.csv')

# %%
x
# Out:
# [    Unnamed: 0  id  location_id  program_id         accepted_payments  \
#  0          NaN   1            1         NaN                       NaN
#  1          NaN   2            2         NaN                       NaN
#  2          NaN   3            3         NaN                       NaN
#  3          NaN   4            4         NaN                       NaN
#  4          NaN   5            5         NaN                       NaN
#  5          NaN   6            6         NaN                       NaN
#  6          NaN   7            7         NaN                       NaN
#  7          NaN   8            8         NaN                       NaN
#  8          NaN   9            9         NaN                       NaN
#  9          NaN  10           10         NaN                       NaN
#  10         NaN  11           11         NaN                       NaN
#  11         NaN  12           12         NaN                       NaN
# ...
